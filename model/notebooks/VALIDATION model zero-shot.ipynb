# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Загрузка данных

# %%
data_manual = pd.read_csv('../data/all_reviews_manual.csv')

# %%
data_pipeline = pd.read_csv('../data/all_reviews_pipeline.csv')

# %% [markdown]
# # Ручной просмотр

# %%
data_manual.head()
# Out:
#   store_name   store_type             store_address store_district  \
# 0      Дикси  Супермаркет  Суворовский проспект, 36   Смольнинское
# 1      Дикси  Супермаркет  Суворовский проспект, 36   Смольнинское
# 2  Пятерочка  Супермаркет   Лиговский проспект, 107   Владимирский
# 3      Дикси  Супермаркет     Большая Московская, 5   Владимирский
# 4      Дикси  Супермаркет           Чайковского, 55       Литейный
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         text  \
# ...

# %%
data_pipeline.head()
# Out:
#   store_name   store_type             store_address store_district  \
# 0      Дикси  Супермаркет  Суворовский проспект, 36   Смольнинское
# 1      Дикси  Супермаркет  Суворовский проспект, 36   Смольнинское
# 2  Пятерочка  Супермаркет   Лиговский проспект, 107   Владимирский
# 3      Дикси  Супермаркет     Большая Московская, 5   Владимирский
# 4      Дикси  Супермаркет           Чайковского, 55       Литейный
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         text  \
# ...

# %%
data_pipeline.head(20)
# Out:
#    store_name   store_type             store_address  store_district  \
# 0       Дикси  Супермаркет  Суворовский проспект, 36    Смольнинское
# 1       Дикси  Супермаркет  Суворовский проспект, 36    Смольнинское
# 2   Пятерочка  Супермаркет   Лиговский проспект, 107    Владимирский
# 3       Дикси  Супермаркет     Большая Московская, 5    Владимирский
# 4       Дикси  Супермаркет           Чайковского, 55        Литейный
# 5   Пятерочка  Супермаркет             Разъезжая, 23    Владимирский
# 6   Пятерочка  Супермаркет             Марата, 65/20    Владимирский
# 7   Пятерочка  Супермаркет  Владимирский проспект, 6    Владимирский
# 8    Вкусвилл  Супермаркет     Невский проспект, 130    Смольнинское
# 9   Пятерочка  Супермаркет     Невский проспект, 146    Смольнинское
# 10  Пятерочка  Супермаркет       Черняховского, 16/5  Лиговка-Ямская
# 11  Пятерочка  Супермаркет  Суворовский проспект, 10    Смольнинское
# 12      Дикси  Супермаркет     Большая Московская, 5    Владимирский
# ...
